# %%
from colorsort_img import read_img, process_img
from colorsort_game import plot_tubes, playGame
from colorsort_solver import seq_increment, seq_backtrack, random_search

import matplotlib.pyplot as plt

# %%
tubes_img = read_img("tubes.jpeg")
plt.imshow(tubes_img)

# %%
tubes = process_img("tubes.jpeg")
plot_tubes(tubes)

# %%
moves = seq_backtrack(tubes)
playGame(tubes, moves)
# Out:
# run 0, max_moves = 1
# move:1 -> transfer tube6 to tube8
# move:2 -> transfer tube7 to tube9
# move:3 -> transfer tube1 to tube7
# move:4 -> transfer tube2 to tube7
# move:5 -> transfer tube2 to tube9
# move:6 -> transfer tube1 to tube6
# move:7 -> transfer tube1 to tube2
# move:8 -> transfer tube1 to tube6
# move:9 -> transfer tube6 to tube1
# move:10 -> transfer tube5 to tube6
# move:11 -> transfer tube5 to tube8
# move:12 -> transfer tube5 to tube9
# move:13 -> transfer tube1 to tube5
# move:14 -> transfer tube7 to tube1
# move:15 -> transfer tube6 to tube7
# move:16 -> transfer tube3 to tube6
# move:17 -> transfer tube3 to tube7
# move:18 -> transfer tube4 to tube3
# move:19 -> transfer tube4 to tube2
# move:20 -> transfer tube3 to tube6
# move:21 -> transfer tube4 to tube8
# move:22 -> transfer tube1 to tube4
