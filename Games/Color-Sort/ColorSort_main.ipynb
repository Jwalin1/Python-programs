# %%
from colorsort_img import read_img, process_img
from colorsort_game import plot_tubes, playGame
from colorsort_solver import seq_increment, seq_backtrack, random_search

import matplotlib.pyplot as plt

# %%
tubes_img = read_img("tubes.jpeg")
plt.imshow(tubes_img)

# %%
tubes = process_img("tubes.jpeg")
plot_tubes(tubes)

# %%
moves = seq_backtrack(tubes, shuffle=True)
playGame(tubes, moves)
# Out:
# run 0, max_moves = 1
# run 1000, max_moves = 27
# move:1 -> transfer tube5 to tube13
# move:2 -> transfer tube12 to tube5
# move:3 -> transfer tube5 to tube14
# move:4 -> transfer tube6 to tube14
# move:5 -> transfer tube4 to tube5
# move:6 -> transfer tube7 to tube5
# move:7 -> transfer tube4 to tube12
# move:8 -> transfer tube6 to tube7
# move:9 -> transfer tube13 to tube6
# move:10 -> transfer tube5 to tube13
# move:11 -> transfer tube11 to tube5
# move:12 -> transfer tube10 to tube11
# move:13 -> transfer tube1 to tube4
# move:14 -> transfer tube1 to tube10
# move:15 -> transfer tube6 to tube1
# move:16 -> transfer tube13 to tube6
# move:17 -> transfer tube11 to tube13
# move:18 -> transfer tube10 to tube11
# move:19 -> transfer tube4 to tube10
# move:20 -> transfer tube2 to tube4
# move:21 -> transfer tube8 to tube4
# move:22 -> transfer tube8 to tube13
# move:23 -> transfer tube5 to tube8
# move:24 -> transfer tube11 to tube5
# move:25 -> transfer tube3 to tube5
# move:26 -> transfer tube2 to tube3
# move:27 -> transfer tube11 to tube2
# move:28 -> transfer tube12 to tube11
# move:29 -> transfer tube12 to tube4
# move:30 -> transfer tube10 to tube12
# move:31 -> transfer tube10 to tube2
# move:32 -> transfer tube2 to tube10
# move:33 -> transfer tube13 to tube2
# move:34 -> transfer tube1 to tube13
# move:35 -> transfer tube12 to tube1
# move:36 -> transfer tube7 to tube12
# move:37 -> transfer tube10 to tube7
# move:38 -> transfer tube8 to tube10
# move:39 -> transfer tube3 to tube8
# move:40 -> transfer tube3 to tube13
# move:41 -> transfer tube3 to tube11
# move:42 -> transfer tube9 to tube8
# move:43 -> transfer tube9 to tube12
# move:44 -> transfer tube9 to tube10
# move:45 -> transfer tube9 to tube14
