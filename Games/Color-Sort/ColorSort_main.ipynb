# %%
from colorsort_img import read_img, process_img
from colorsort_game import plot_tubes, playGame
from colorsort_solver import seq_increment, seq_backtrack, random_search

import matplotlib.pyplot as plt

# %%
tubes_img = read_img("tubes.jpeg")
plt.imshow(tubes_img)
plt.show()

# %%
tubes = process_img("tubes.jpeg")
plot_tubes(tubes)

# %%
moves = seq_backtrack(tubes, shuffle=True)
playGame(tubes, moves)
# Out:
# found solution in run 51
# move:1 -> transfer tube3 to tube13
# move:2 -> transfer tube10 to tube3
# move:3 -> transfer tube3 to tube14
# move:4 -> transfer tube1 to tube14
# move:5 -> transfer tube2 to tube14
# move:6 -> transfer tube9 to tube3
# move:7 -> transfer tube9 to tube13
# move:8 -> transfer tube5 to tube13
# move:9 -> transfer tube10 to tube5
# move:10 -> transfer tube10 to tube1
# move:11 -> transfer tube3 to tube10
# move:12 -> transfer tube3 to tube9
# move:13 -> transfer tube9 to tube3
# move:14 -> transfer tube6 to tube9
# move:15 -> transfer tube6 to tube3
# move:16 -> transfer tube7 to tube6
# move:17 -> transfer tube7 to tube3
# move:18 -> transfer tube7 to tube10
# move:19 -> transfer tube5 to tube7
# move:20 -> transfer tube9 to tube5
# move:21 -> transfer tube6 to tube9
# move:22 -> transfer tube6 to tube2
# move:23 -> transfer tube2 to tube6
# move:24 -> transfer tube9 to tube2
# move:25 -> transfer tube1 to tube9
# move:26 -> transfer tube4 to tube1
# ...
